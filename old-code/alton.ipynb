# %% [markdown]
# # get urls

# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
from pathlib import Path
import pandas as pd

# %%
base_url_alton = "https://www.foodnetwork.com/profiles/talent/alton-brown/recipes" + "/recentlyaired-/p/{}", 54
base_url_show = "https://www.foodnetwork.com/shows/good-eats/recipes" + "/recentlyaired-/p/{}", 46

# %%
def template_to_urls(template, max):
    return [template.format(i) for i in range(1, max+1)]
    
def get_soup(url):
    response = requests.get(url)
    if not response.ok:
        raise ValueError("{} could not be retrieved.".format(url))
    return BeautifulSoup(response.text, "lxml")

def soup_to_reviews(soup):
    recipe_reviews = {
        "https:" + item.a.get("href") :
        (
            item.find(attrs={'class': "gig-rating-stars"}).get('title') if item.find(attrs={'class': "gig-rating-stars"}) else None, 
            item.find(attrs={'class': "gig-rating-ratingsum"}).text if item.find(attrs={'class': "gig-rating-ratingsum"}) else None,
        )
        for item in soup.find(attrs={'class': "l-List"}).find_all(attrs={'class': "m-MediaBlock__m-TextWrap"})
    }
    
    return recipe_reviews

def soup_to_recipes(soup):
    recipe_urls = [
        "https:" + item.a.get("href") 
        for item in soup.find(attrs={'class': "l-List"}).find_all(attrs={'class': "m-MediaBlock__m-TextWrap"})
    ]
    return recipe_urls

# %%
recipe_urls1 = {}
for url in tqdm(template_to_urls(*base_url_alton)):
    new_urls = soup_to_reviews(get_soup(url))
    if len(new_urls) != 15:
        print(len(new_urls), url)
    recipe_urls1.update(**new_urls)

print(len(recipe_urls1.keys()), '>', len(set(recipe_urls1.keys())))
# Out:
#   0%|                                                                                           | 0/54 [00:00<?, ?it/s]
#   2%|█▌                                                                                 | 1/54 [00:00<00:16,  3.17it/s]
#   4%|███                                                                                | 2/54 [00:00<00:16,  3.16it/s]
#   6%|████▌                                                                              | 3/54 [00:01<00:27,  1.84it/s]
#   7%|██████▏                                                                            | 4/54 [00:02<00:25,  1.96it/s]
#   9%|███████▋                                                                           | 5/54 [00:02<00:21,  2.26it/s]
#  11%|█████████▏                                                                         | 6/54 [00:02<00:19,  2.47it/s]
#  13%|██████████▊                                                                        | 7/54 [00:03<00:17,  2.75it/s]
#  15%|████████████▎                                                                      | 8/54 [00:03<00:15,  2.98it/s]
#  17%|█████████████▊                                                                     | 9/54 [00:03<00:14,  3.16it/s]
#  19%|███████████████▏                                                                  | 10/54 [00:03<00:14,  2.98it/s]
#  20%|████████████████▋                                                                 | 11/54 [00:04<00:14,  3.04it/s]
#  22%|██████████████████▏                                                               | 12/54 [00:04<00:13,  3.08it/s]
#  24%|███████████████████▋                                                              | 13/54 [00:04<00:12,  3.28it/s]
#  26%|█████████████████████▎                                                            | 14/54 [00:05<00:12,  3.28it/s]
#  28%|██████████████████████▊                                                           | 15/54 [00:05<00:11,  3.30it/s]
#  30%|████████████████████████▎                                                         | 16/54 [00:05<00:11,  3.25it/s]
#  31%|█████████████████████████▊                                                        | 17/54 [00:06<00:11,  3.29it/s]
#  33%|███████████████████████████▎                                                      | 18/54 [00:06<00:10,  3.34it/s]
#  35%|████████████████████████████▊                                                     | 19/54 [00:07<00:19,  1.81it/s]
/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 54/54 [00:38<00:00,  1.30s/it]
# 585 > 585

# %%
recipe_urls2 = {}
for url in tqdm(template_to_urls(*base_url_show)):
    new_urls = soup_to_reviews(get_soup(url))
    if len(new_urls) != 15:
        print(len(new_urls), url)
    recipe_urls2.update(**new_urls)

print(len(recipe_urls2.keys()), '>', len(set(recipe_urls2.keys())))
# Out:
#   0%|                                                                                           | 0/46 [00:00<?, ?it/s]
#   2%|█▊                                                                                 | 1/46 [00:01<01:23,  1.86s/it]
#   4%|███▌                                                                               | 2/46 [00:03<01:24,  1.92s/it]
#   7%|█████▍                                                                             | 3/46 [00:05<01:12,  1.68s/it]
#   9%|███████▏                                                                           | 4/46 [00:06<01:02,  1.50s/it]
#  11%|█████████                                                                          | 5/46 [00:07<00:57,  1.40s/it]
#  13%|██████████▊                                                                        | 6/46 [00:08<00:51,  1.29s/it]
#  15%|████████████▋                                                                      | 7/46 [00:10<00:56,  1.44s/it]
#  17%|██████████████▍                                                                    | 8/46 [00:11<00:50,  1.33s/it]
#  20%|████████████████▏                                                                  | 9/46 [00:12<00:46,  1.25s/it]
#  22%|█████████████████▊                                                                | 10/46 [00:13<00:42,  1.18s/it]
#  24%|███████████████████▌                                                              | 11/46 [00:14<00:39,  1.13s/it]

# %%
df_reviews = pd.DataFrame()
for url, v in recipe_urls1.items():
    name = url.split('/')[-1]
    reviews = int(v[1].split(' ')[0]) if v[1] else None
    stars = float(v[0].split(' ')[0]) if v[0] else None
    assert name not in df_reviews.index
    df_reviews = df_reviews.append(pd.Series(data={'url': url, 'stars': stars, 'reviews': reviews}, name=name))
for url, v in recipe_urls2.items():
    name = url.split('/')[-1]
    reviews = int(v[1].split(' ')[0]) if v[1] else None
    stars = float(v[0].split(' ')[0]) if v[0] else None
    if name in df_reviews.index:
        assert df_reviews.loc[name,'url'] == url
        if stars: assert df_reviews.loc[name,'stars'] == stars
        if reviews: assert df_reviews.loc[name,'reviews'] == reviews
        continue
    df_reviews = df_reviews.append(pd.Series(data={'url': url, 'stars': stars, 'reviews': reviews}, name=name))
df_reviews.sort_values(['stars', 'reviews'], ascending=False).head(10)
# Out:
#                                               reviews  stars  \
# good-eats-roast-turkey-recipe-1950271          5419.0    5.0
# the-chewy-recipe-1909046                       1137.0    5.0
# who-loves-ya-baby-back-recipe-1937448          1052.0    5.0
# instant-pancake-mix-recipe-1938544              712.0    5.0
# pan-seared-rib-eye-recipe-2131274               655.0    5.0
# french-toast-recipe-1942216                     639.0    5.0
# homemade-soft-pretzels-recipe-1948242           626.0    5.0
# southern-biscuits-recipe-2041990                616.0    5.0
# hot-spinach-and-artichoke-dip-recipe-1912620    556.0    5.0
# shepherds-pie-recipe2-1942900                   530.0    5.0
#
#                                                                                             url
# good-eats-roast-turkey-recipe-1950271         https://www.foodnetwork.com/recipes/alton-brow...
# the-chewy-recipe-1909046                      https://www.foodnetwork.com/recipes/alton-brow...
# who-loves-ya-baby-back-recipe-1937448         https://www.foodnetwork.com/recipes/alton-brow...
# instant-pancake-mix-recipe-1938544            https://www.foodnetwork.com/recipes/alton-brow...
# pan-seared-rib-eye-recipe-2131274             https://www.foodnetwork.com/recipes/alton-brow...
# french-toast-recipe-1942216                   https://www.foodnetwork.com/recipes/alton-brow...
# homemade-soft-pretzels-recipe-1948242         https://www.foodnetwork.com/recipes/alton-brow...
# southern-biscuits-recipe-2041990              https://www.foodnetwork.com/recipes/alton-brow...
# hot-spinach-and-artichoke-dip-recipe-1912620  https://www.foodnetwork.com/recipes/alton-brow...
# shepherds-pie-recipe2-1942900                 https://www.foodnetwork.com/recipes/alton-brow...

# %%
sorted_recipe_urls = set(sorted_recipe_urls1).union(sorted_recipe_urls2)
print(len(sorted_recipe_urls))

# %%
Path('sorted_recipe_urls.txt').write_text('\n'.join(sorted_recipe_urls))
assert sorted_recipe_urls == set(Path('sorted_recipe_urls.txt').read_text().split('\n'))
# Out:
# True

# %%
a = sorted_recipe_urls
b = set(df_reviews.url.values)
len(a), len(b), len(a-b), len(b-a), len(a.union(b))
# Out:
# (675, 683, 99, 107, 782)

# %%
set(df_reviews.url.values) - sorted_recipe_urls
# Out:
# {'https://www.foodnetwork.com/recipes/alton-brown/acid-jellies-recipe-1941929',
#  'https://www.foodnetwork.com/recipes/alton-brown/alton-browns-buffalo-wings-recipe-1972721',
#  'https://www.foodnetwork.com/recipes/alton-brown/angel-food-cake-recipe-1938726',
#  'https://www.foodnetwork.com/recipes/alton-brown/avocado-buttercream-frosting-recipe-1945000',
#  'https://www.foodnetwork.com/recipes/alton-brown/baked-greens-chips-recipe-1961387',
#  'https://www.foodnetwork.com/recipes/alton-brown/baked-macaroni-and-cheese-1-3644279',
#  'https://www.foodnetwork.com/recipes/alton-brown/barbecue-pork-butt-recipe-2047110',
#  'https://www.foodnetwork.com/recipes/alton-brown/barley-and-lamb-stew-recipe-1945927',
#  'https://www.foodnetwork.com/recipes/alton-brown/basic-popovers-recipe-1973913',
#  'https://www.foodnetwork.com/recipes/alton-brown/beef-paillard-recipe-1915465',
#  'https://www.foodnetwork.com/recipes/alton-brown/best-ever-green-bean-casserole-recipe-1950575',
#  'https://www.foodnetwork.com/recipes/alton-brown/bird-to-the-last-drop-recipe-1937879',
#  'https://www.foodnetwork.com/recipes/alton-brown/black-pepper-mango-sorbet-recipe-2103944',
#  'https://www.foodnetwork.com/recipes/alton-brown/blue-cheese-dressing-recipe-1959913',
#  'https://www.foodnetwork.com/recipes/alton-brown/boiled-peanuts-recipe-1950535',
#  'https://www.foodnetwork.com/recipes/alton-brown/bourbon-pecan-pie-recipe-2041499',
#  'https://www.foodnetwork.com/recipes/alton-brown/carrot-slaw-recipe-1943995',
#  'https://www.foodnetwork.com/recipes/alton-brown/cashew-sauce-recipe-1942375',
#  'https://www.foodnetwork.com/recipes/alton-brown/catfish-au-lait-recipe-1938494',
#  'https://www.foodnetwork.com/recipes/alton-brown/catfish-soup-recipe-1919052',
#  'https://www.foodnetwork.com/recipes/alton-brown/chicken-kiev-recipe-1952333',
#  'https://www.foodnetwork.com/recipes/alton-brown/the-shrimp-cocktail-recipe-1927450',
#  'https://www.foodnetwork.com/recipes/alton-brown/traditional-roast-turkey-recipe-2010390',
#  'https://www.foodnetwork.com/recipes/alton-brown/turbo-hummus-recipe-1909491',
#  'https://www.foodnetwork.com/recipes/alton-brown/turkey-giblet-gravy-recipe-2124665',
#  'https://www.foodnetwork.com/recipes/alton-brown/vegetable-saute-recipe-1940676',
#  'https://www.foodnetwork.com/recipes/alton-brown/wet-fried-calamari-recipe-1946675',
#  'https://www.foodnetwork.com/recipes/alton-brown/whipped-cream-recipe-1957526',
#  'https://www.foodnetwork.com/recipes/alton-brown/whipped-potatoes-recipe-2106587',
#  'https://www.foodnetwork.com/recipes/alton-brown/zaatar-recipe-1959755',
#  'https://www.foodnetwork.com/recipes/alton-brown/zabaglione-recipe-1918514',
#  'https://www.foodnetwork.com/recipes/chocolate-chiffon-cupcake-recipe-1938916',
#  'https://www.foodnetwork.com/recipes/gravy-from-roast-drippings-recipe-1951306',
#  'https://www.foodnetwork.com/recipes/grilled-salmon-steaks-recipe0-1956916',
#  'https://www.foodnetwork.com/recipes/knead-not-sourdough-recipe-1939606',
#  'https://www.foodnetwork.com/recipes/lemon-ginger-frozen-yogurt-recipe-1939742',
#  'https://www.foodnetwork.com/recipes/pan-fried-fish-recipe-1910675',
#  'https://www.foodnetwork.com/recipes/sawmill-gravy-recipe0-1957150',
#  'https://www.foodnetwork.com/recipes/shortcake-recipe-1910146'}

# %%
sorted_recipe_urls - set(df_reviews.url.values)
# Out:
# {'https://www.foodnetwork.com/recipes/alton-brown/abs-martini-recipe-1945331',
#  'https://www.foodnetwork.com/recipes/alton-brown/all-american-beef-taco-recipe-2014469',
#  'https://www.foodnetwork.com/recipes/alton-brown/alton-brown-ma-maes-congealed-christmas-salad-recipe-1965065',
#  'https://www.foodnetwork.com/recipes/alton-brown/ants-in-trees-recipe-1923962',
#  'https://www.foodnetwork.com/recipes/alton-brown/atomic-apples-recipe-1922083',
#  'https://www.foodnetwork.com/recipes/alton-brown/backyard-baby-back-ribs-recipe-1947134',
#  'https://www.foodnetwork.com/recipes/alton-brown/bacon-vinaigrette-with-grilled-radicchio-recipe-1939636',
#  'https://www.foodnetwork.com/recipes/alton-brown/baked-macaroni-and-cheese-1939524',
#  'https://www.foodnetwork.com/recipes/alton-brown/baklava-recipe-1943974',
#  'https://www.foodnetwork.com/recipes/alton-brown/beer-bread-recipe-1949292',
#  'https://www.foodnetwork.com/recipes/alton-brown/beet-slaw-recipe-1940942',
#  'https://www.foodnetwork.com/recipes/alton-brown/best-gravy-ever-recipe-2009748',
#  'https://www.foodnetwork.com/recipes/alton-brown/bi-level-king-salmon-fillet-recipe-1946102',
#  'https://www.foodnetwork.com/recipes/alton-brown/black-bean-salad-recipe-1909063',
#  'https://www.foodnetwork.com/recipes/alton-brown/bloody-marys-with-tomato-vodka-3363142',
#  'https://www.foodnetwork.com/recipes/alton-brown/blueberry-buckle-recipe-2012987',
#  'https://www.foodnetwork.com/recipes/alton-brown/blueberry-soda-recipe-1950476',
#  'https://www.foodnetwork.com/recipes/alton-brown/braised-celery-recipe-1939479',
#  'https://www.foodnetwork.com/recipes/alton-brown/brined-and-smoked-smelt-recipe-1957677',
#  'https://www.foodnetwork.com/recipes/alton-brown/broiled-chokes-recipe-1939939',
#  'https://www.foodnetwork.com/recipes/alton-brown/buff-smoothie-recipe-2014144',
#  'https://www.foodnetwork.com/recipes/alton-brown/burned-peach-ice-cream-recipe-1918519',
#  'https://www.foodnetwork.com/recipes/alton-brown/buttermilk-pound-cake-recipe-1949033',
#  'https://www.foodnetwork.com/recipes/alton-brown/candy-corn-recipe2-2120004',
#  'https://www.foodnetwork.com/recipes/alton-brown/cauliflower-say-cheese-recipe-1923976',
#  'https://www.foodnetwork.com/recipes/alton-brown/cherry-couscous-pudding-recipe-1941940',
#  'https://www.foodnetwork.com/recipes/alton-brown/chicken-and-dropped-dumplings-recipe-1949787',
#  'https://www.foodnetwork.com/recipes/alton-brown/chocolate-coconut-balls-recipe-1913124',
#  'https://www.foodnetwork.com/recipes/alton-brown/clotted-cream-recipe4-1956887',
#  'https://www.foodnetwork.com/recipes/alton-brown/cocoa-brownies-recipe-2085484',
#  'https://www.foodnetwork.com/recipes/alton-brown/cranberry-sauce-3645117',
#  'https://www.foodnetwork.com/recipes/alton-brown/creamy-mashed-potatoes-recipe-1956220',
#  'https://www.foodnetwork.com/recipes/alton-brown/crepe-quiche-lorraine-recipe2-2112082',
#  'https://www.foodnetwork.com/recipes/alton-brown/crepes-suzette-recipe-1939388',
#  'https://www.foodnetwork.com/recipes/alton-brown/curry-chicken-pot-pie-recipe-1912950',
#  'https://www.foodnetwork.com/recipes/alton-brown/eggplant-pasta-recipe-1911359',
#  'https://www.foodnetwork.com/recipes/alton-brown/english-muffins-recipe-1953408',
#  'https://www.foodnetwork.com/recipes/alton-brown/faux-peanut-sauce-recipe-1947832',
#  'https://www.foodnetwork.com/recipes/alton-brown/free-range-fruitcake-recipe-1926833',
#  'https://www.foodnetwork.com/recipes/alton-brown/french-onion-soup-recipe2-1938467',
#  'https://www.foodnetwork.com/recipes/alton-brown/frozen-strawberries-recipe4-1956990',
#  'https://www.foodnetwork.com/recipes/alton-brown/ge-court-bouillon-recipe-1938582',
#  'https://www.foodnetwork.com/recipes/alton-brown/ginger-snaps-recipe2-1962290',
#  'https://www.foodnetwork.com/recipes/alton-brown/glazed-baby-beets-recipe-1940920',
#  'https://www.foodnetwork.com/recipes/alton-brown/good-gravy-3381448',
#  'https://www.foodnetwork.com/recipes/alton-brown/graham-crackers-recipe-1943365',
#  'https://www.foodnetwork.com/recipes/alton-brown/grape-gazpacho-recipe-1943522',
#  'https://www.foodnetwork.com/recipes/alton-brown/grilled-romaine-recipe-1944496',
#  'https://www.foodnetwork.com/recipes/alton-brown/guacamole-recipe-1940609',
#  'https://www.foodnetwork.com/recipes/alton-brown/honey-mustard-dressing-recipe-1939031',
#  'https://www.foodnetwork.com/recipes/alton-brown/hot-tamales-recipe-2011883',
#  'https://www.foodnetwork.com/recipes/alton-brown/hummus-in-a-hurry-recipe-2111758',
#  'https://www.foodnetwork.com/recipes/alton-brown/summer-fruits-recipe-1938008',
#  'https://www.foodnetwork.com/recipes/alton-brown/swedish-meatballs-recipe-1916539',
#  'https://www.foodnetwork.com/recipes/alton-brown/that-ol-cap-magic-recipe-1927723',
#  'https://www.foodnetwork.com/recipes/alton-brown/vanilla-wafers-recipe-1920909',
#  'https://www.foodnetwork.com/recipes/alton-brown/vegetarian-steamed-dumplings-recipe-1942919',
#  'https://www.foodnetwork.com/recipes/alton-brown/veni-vedi-vinaigrette-recipe-1909937',
#  'https://www.foodnetwork.com/recipes/alton-brown/wassail-recipe-1949056',
#  'https://www.foodnetwork.com/recipes/alton-brown/wet-fried-okra-recipe-1946494',
#  'https://www.foodnetwork.com/recipes/alton-brown/white-roux-recipe-1938250',
#  'https://www.foodnetwork.com/recipes/alton-brown/yorkshire-pudding-with-roast-recipe-1939474',
#  'https://www.foodnetwork.com/recipes/dutch-oven-cherry-clafouti-recipe-2047259',
#  'https://www.foodnetwork.com/recipes/striped-bass-in-salt-dome-recipe0-1957076',
#  'https://www.foodnetwork.com/recipes/white-roux-recipe-1939081'}

# %% [markdown]
# # get recipes

# %%
import requests
from tqdm import tqdm
from pathlib import Path

# %%
sorted_recipe_urls = set(Path('sorted_recipe_urls.txt').read_text().split('\n'))

# %%
def download_urls(urls):
    skipped = []
    error = []
    downloaded = []
    for url in tqdm(urls):
        filename = Path('/'.join(url.split('//')[1].split('/')[1:]) + '.html')
        if filename.exists() and filename.read_text(encoding='utf8').strip():
            skipped += [url]
            continue
        filename.parent.mkdir(parents=True, exist_ok=True)

        response = requests.get(url)
        if not response.ok:
            error += [url]
            continue
        text = response.text
        
        filename.write_text(text, encoding='utf8')
        downloaded += [url]
    print(f'skipped: {len(skipped)}  error: {len(error)}  downloaded: {len(downloaded)}  TOTAL: {len(skipped + error + downloaded)}')


download_urls(sorted_recipe_urls)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 675/675 [01:09<00:00,  9.77it/s]
# skipped: 675  error: 0  downloaded: 0  TOTAL: 675

# %% [markdown]
# # process recipes

# %%
from bs4 import BeautifulSoup
from tqdm import tqdm
from pathlib import Path
import json

# %%
recipe_files = sorted(Path('recipes').glob('**/*.html'))
recipe_files[:5]
# Out:
# [WindowsPath('recipes/alton-brown/10-minute-apple-sauce-recipe-1950796.html'),
#  WindowsPath('recipes/alton-brown/10-minute-apple-sauce-recipe2-1938289.html'),
#  WindowsPath('recipes/alton-brown/4-pepper-deviled-eggs-recipe-1917393.html'),
#  WindowsPath('recipes/alton-brown/40-cloves-and-a-chicken-recipe-1910661.html'),
#  WindowsPath('recipes/alton-brown/abs-b-and-bs-recipe-1908804.html')]

# %%
def file_to_soup(filename):
    return BeautifulSoup(Path(filename).read_text(encoding='utf8'), 'lxml')


def soup_to_data(soup):
    ret = {}
    recipe = soup.find(attrs={'class': "o-Recipe"})
    if not recipe:
        return None
    # summary
    recipe_summary = recipe.find(attrs={'class': "m-RecipeSummary"})
    ret['Title'] = recipe_summary.find(attrs={'class': "o-AssetTitle__a-HeadlineText"}).text
    ret['Author'] = recipe_summary.find(attrs={'class': "o-Attribution__m-TextWrap"}).a.text
    ret['Rating_stars'] = recipe_summary.find(attrs={'class': "gig-rating-stars "})
    ret['Rating_stars'] = ret['Rating_stars'] and ret['Rating_stars'].get('title')
    ret['Rating_num'] = recipe_summary.find(attrs={'class': "gig-rating-ratingsum "})
    ret['Rating_num'] = ret['Rating_num'] and ret['Rating_num'].text
    recipe_info = recipe_summary.find(attrs={'class': "o-RecipeInfo"})
    for ul in recipe_info.find_all('ul'):
        for li in ul.find_all('li'):
            span1, *span2 = li.find_all('span')
            k = span1.text.strip(':').strip()
            v = '\n'.join(s.text.strip() for s in span2)
            assert k not in ret
            ret[k] = v
    # footer
    recipe_footer = recipe.find(attrs={'class': "recipe-body-footer"})
    recipe_sources = recipe_footer.find(attrs={'class': "o-VideoPromo"})
    if recipe_sources:
        for recipe_source in recipe_sources.find_all(attrs={'class': "m-MediaBlock__a-Source"}):
            span1, *span2 = recipe_source.find_all('span')
            k = span1.text.strip(':').strip()
            if k == "Episodes":
                k = k[:-1]
            v = '\n'.join(s.text.strip() for s in span2)
            assert k not in ret
            ret[k] = v
    recipe_tags = recipe_footer.find(attrs={'class': "o-Capsule__m-TagList m-TagList"})
    if recipe_tags:
        ret['Categories'] = ';'.join([tag.text for tag in recipe_tags.find_all('a')])
    # body / ingredients
    ingredients = recipe.find(attrs={'class': "o-Ingredients__m-Body"})
    if ingredients:
        ingredient_title = "Ingredients"
        section_count = 0
        ret[ingredient_title] = []
        for ingredient in ingredients.find_all(['p', 'h6']):
            if ingredient.name == 'p':
                ret[ingredient_title] += [ingredient.text]
            else:
                section = ingredient.text.strip().strip(':')
                section_count += 1
                ingredient_title = f"Ingredients.{section_count}.{section}"
                assert ingredient_title not in ret
                ret[ingredient_title] = []
    # body / method
    method = recipe.find(attrs={'class': "o-Method__m-Body"})
    ret['Directions'] = [li.text.strip() for li in method.find_all('li')]
    return ret

# soup = file_to_soup(recipe_files[22])
# soup_to_data(soup)

# %%
data = {}
for filename in tqdm(recipe_files):
    k = filename.name.split('.')[0].split('-')[-1]
    while k in data:
        k += '_'
    data[k] = soup_to_data(file_to_soup(filename))
    if data[k] is None:
        print(f"{k} couldn't parse as recipe")
# Out:
#  66%|████████████████████████████████████████████████████▊                           | 446/675 [01:57<00:58,  3.92it/s]
# 2047369 couldn't parse as recipe
# 100%|████████████████████████████████████████████████████████████████████████████████| 675/675 [02:54<00:00,  4.65it/s]

# %%
with Path('recipe_data.json').open(mode='w') as f:
    json.dump(data, f)
with Path('recipe_data.json').open() as f:
    assert data == json.load(f)

# %% [markdown]
# # data

# %%
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import json

# %%
with Path('recipe_data.json').open() as f:
    data = json.load(f)

# %%
df = pd.DataFrame()
for name, d in tqdm(data.items(), leave=False):
    if d:
        d2 = d.copy()
        if "Ingredients" in d2:
            ing_len = 0
            for k in list(d2):
                if k.startswith("Ingredients"):
                    ing_len += len(d2.pop(k))
            d2["n_Ingredients"] = ing_len
        if "Directions" in d2:
            d2["n_Directions"] = len(d2.pop("Directions"))
        df = df.append(pd.Series(d2, name=name.split('-')[-1]))
    else:
        df = df.append(pd.Series(name=name.split('-')[-1]))
new_col_order = [k for k in d2.keys() if k in df.columns] + [c for c in df.columns if c not in (d2.keys())]
df = df[new_col_order]

df.index.name = "foodnetwork_id"
df['Author'] = df['Author'].str.replace("Recipe courtesy of ", "").astype('category')
df['Rating_stars'] = df['Rating_stars'].replace('pending rating', pd.np.NaN).astype(float)
df['Rating_num'] = df['Rating_num'].astype(float)  # Int
df['Level'] = df['Level'].astype('category')
df['Show'] = df['Show'].astype('category')
df['n_Ingredients'] = df['n_Ingredients'].astype(float)  # Int
df['n_Directions'] = df['n_Directions'].astype(float)  # Int
df['Nutrition Info'] = df['Nutrition Info'].str.strip().replace('', pd.np.NaN)
total = df.Total.str.split('\n', expand=True)
df['Total'] = total[0]
df['note_Total'] = total[1].dropna()
for c in 'Total Cook Inactive Prep Active'.split():
    df[f't_{c}'] = pd.to_timedelta(df.pop(c))
df = df.dropna(axis=1, how='all')

df.head()
# Out:
#                                   Title       Author         Level  \
# foodnetwork_id
# 1950796           10 Minute Apple Sauce  Alton Brown          Easy
# 1938289           10 Minute Apple Sauce  Alton Brown           NaN
# 1917393           4-Pepper Deviled Eggs  Alton Brown          Easy
# 1910661         40 Cloves and a Chicken  Alton Brown  Intermediate
# 1908804                  Ab's B and B's  Alton Brown           NaN
#
#                           Yield       Show                            Episode  \
# foodnetwork_id
# 1950796                 1 quart  Good Eats                Apple Family Values
# 1938289                 1 quart  Good Eats             Cable in the Classroom
# 1917393         12 deviled eggs  Good Eats                       Major Pepper
# 1910661              6 servings  Good Eats  In The Bulb of the Night (Garlic)
# 1908804              4 servings  Good Eats                    American Pickle
#
#                                                        Categories  \
# foodnetwork_id
# 1950796         Easy Side Dish Recipes;Easy;Side Dish;Sauce Re...
# 1938289         Sauce Recipes;Apple;Fruit;Side Dish;Fall;Puree...
# 1917393         American;Deviled Egg;Easter;Holiday;Egg Recipe...
# 1910661         Healthy;Chicken;Poultry;Main Dish;Low Sodium;L...
# 1908804         Pickle Recipes;Celery;Vegetable;Cucumber;Glute...
#
#                 n_Ingredients  n_Directions note_Total  t_Total   t_Cook  \
# foodnetwork_id
# 1950796                   7.0           2.0        NaN      NaT      NaT
# 1938289                   7.0           2.0        NaN      NaT      NaT
# 1917393                  10.0           2.0        NaN 02:00:00 00:10:00
# 1910661                   5.0           3.0        NaN 01:40:00 01:30:00
# 1908804                  10.0           4.0        NaN      NaT      NaT
#
#                t_Inactive   t_Prep t_Active
# foodnetwork_id
# 1950796               NaT      NaT      NaT
# 1938289               NaT      NaT      NaT
# 1917393          01:30:00 00:20:00      NaT
# 1910661               NaT 00:10:00      NaT
# 1908804               NaT      NaT      NaT

# %%
df.dtypes
# Out:
# Title                     object
# Author                  category
# Level                   category
# Yield                     object
# Show                    category
# Episode                   object
# Categories                object
# n_Ingredients            float64
# n_Directions             float64
# note_Total                object
# t_Total          timedelta64[ns]
# t_Cook           timedelta64[ns]
# t_Inactive       timedelta64[ns]
# t_Prep           timedelta64[ns]
# t_Active         timedelta64[ns]
# dtype: object

# %%
df.to_pickle('recipe_df.pickle')
assert pd.read_pickle('recipe_df.pickle').equals(df)

# %% [markdown]
# # use DF

# %%
import pandas as pd
import pint
from pprint import pprint

# %%
df = pd.read_pickle('recipe_df.pickle')
df.head()
# Out:
#                                   Title       Author         Level  \
# foodnetwork_id
# 1950796           10 Minute Apple Sauce  Alton Brown          Easy
# 1938289           10 Minute Apple Sauce  Alton Brown           NaN
# 1917393           4-Pepper Deviled Eggs  Alton Brown          Easy
# 1910661         40 Cloves and a Chicken  Alton Brown  Intermediate
# 1908804                  Ab's B and B's  Alton Brown           NaN
#
#                           Yield       Show                            Episode  \
# foodnetwork_id
# 1950796                 1 quart  Good Eats                Apple Family Values
# 1938289                 1 quart  Good Eats             Cable in the Classroom
# 1917393         12 deviled eggs  Good Eats                       Major Pepper
# 1910661              6 servings  Good Eats  In The Bulb of the Night (Garlic)
# 1908804              4 servings  Good Eats                    American Pickle
#
#                                                        Categories  \
# foodnetwork_id
# 1950796         Easy Side Dish Recipes;Easy;Side Dish;Sauce Re...
# 1938289         Sauce Recipes;Apple;Fruit;Side Dish;Fall;Puree...
# 1917393         American;Deviled Egg;Easter;Holiday;Egg Recipe...
# 1910661         Healthy;Chicken;Poultry;Main Dish;Low Sodium;L...
# 1908804         Pickle Recipes;Celery;Vegetable;Cucumber;Glute...
#
#                 n_Ingredients  n_Directions note_Total  t_Total   t_Cook  \
# foodnetwork_id
# 1950796                   7.0           2.0        NaN      NaT      NaT
# 1938289                   7.0           2.0        NaN      NaT      NaT
# 1917393                  10.0           2.0        NaN 02:00:00 00:10:00
# 1910661                   5.0           3.0        NaN 01:40:00 01:30:00
# 1908804                  10.0           4.0        NaN      NaT      NaT
#
#                t_Inactive   t_Prep t_Active
# foodnetwork_id
# 1950796               NaT      NaT      NaT
# 1938289               NaT      NaT      NaT
# 1917393          01:30:00 00:20:00      NaT
# 1910661               NaT 00:10:00      NaT
# 1908804               NaT      NaT      NaT

# %%
df_categories = []
df_categories = pd.Series(sum((cat for cat in df.Categories.str.split(';',).dropna().values if cat), []))
df_categories.value_counts().head(10)
# Out:
# Gluten Free      271
# Vegetable        209
# American         200
# Easy             182
# Fruit            177
# Dessert          163
# Low Sodium       146
# Main Dish        131
# Dairy Recipes    118
# Side Dish        117
# dtype: int64

# %%
pd.Series(df_categories).value_counts().head(25).iloc[::-1].plot.barh(figsize=(6, 6))

# %%
df[df.Categories.str.contains("Crowd") == True][['Title', 'Episode', 'Yield', 't_Total', ]].head(10)
# Out:
#                                                          Title  \
# foodnetwork_id
# 1965065         Alton Brown Ma Mae's Congealed Christmas Salad
# 1950306                                               Ambrosia
# 1939636               Bacon Vinaigrette with Grilled Radicchio
# 1943974                                                Baklava
# 1944590                                       Blackberry Grunt
# 1950476                                         Blueberry Soda
# 1949033                                  Buttermilk Pound Cake
# 2013561         Butternut Dumplings with Brown Butter and Sage
# 1951938                                       Chocolate Mousse
# 1955790                                       Chocolate Mousse
#
#                                              Episode  \
# foodnetwork_id
# 1965065                                          NaN
# 1950306                        Puff the Magic Mallow
# 1939636                              Scrap Iron Chef
# 1943974                          Switched on Baklava
# 1944590                             Cobbled Together
# 1950476                       Kinda Blue (Blueberry)
# 1949033         American Classics V: A Pound of Cake
# 2013561                                 Squash Court
# 1951938                          The Art of Darkness
# 1955790                                          NaN
#
#                                                             Yield  t_Total
# foodnetwork_id
# 1965065                                               10 portions      NaT
# 1950306                                                6 servings 02:30:00
# 1939636                                                8 servings 00:20:00
# 1943974                                           about 28 pieces 10:00:00
# 1944590                                           6 to 8 servings 01:30:00
# 1950476         about 3 cups blueberry syrup, enough for 12 dr... 01:12:00
# 1949033                                         10 to 12 servings 01:40:00
# 2013561                                           6 to 8 servings 01:45:00
# 1951938                                           6 to 8 servings 01:40:00
# 1955790                                           6 to 8 servings      NaT

# %%
c_dict = {'g': ['ounce', 'oz', 'pound']}
def convert_unit(ingredient, convert_dict):
    s = ingredient
    ureg = pint.UnitRegistry()
    ureg.default_format = '.1f'
    try:
        for dst_unit, src_units in convert_dict.items():
            for unit in src_units:
                if unit in s:
                    pos = s.find(' ', s.find(unit))
                    before, after = s[:pos], s[pos:]
                    return str(ureg.Quantity(before).to(dst_unit)) + after
    except pint.DimensionalityError:
        return s
    return s

def convert_units(ingredients, convert_dict):
    return [
        convert_unit(ingredient, convert_dict)
        for ingredient in ingredients
    ]

for k in list(data.keys())[:10]:
    pprint(convert_units(data[k]['Ingredients'], c_dict))
# Out:
# ['3 Golden Delicious apples, peeled, cored, and quartered',
#  '3 Fuji apples, peeled, cored, and quartered',
#  '1 cup unfiltered apple juice',
#  '2 tablespoons cognac or brandy',
#  '2 tablespoons butter',
#  '3 tablespoons honey',
#  '1/2 teaspoon ground cinnamon']
# ['3 Golden Delicious apples, peeled, cored, and quartered',
#  '3 Fuji apples, peeled, cored, and quartered',
#  '1 cup unfiltered apple juice',
#  '2 tablespoons cognac or brandy',
#  '2 tablespoons butter',
#  '3 tablespoons honey',
#  '1/2 teaspoon ground cinnamon']
# ['6 hard boiled eggs, cooled and peeled',
#  '1 teaspoon whole pink peppercorns, divided',
#  '1/2 teaspoon whole white peppercorns',
#  '1/2 teaspoon whole black peppercorns',
#  '1/2 teaspoon whole green peppercorns',
#  '1/2 teaspoon caper liquid',
#  '1/4 cup mayonnaise',
#  '1 teaspoon Dijon mustard',
#  '1/4 teaspoon kosher salt',
#  'Pinch sugar']
# ['1 whole chicken (broiler/fryer) cut into 8 pieces',
#  '1/2 cup plus 2 tablespoons olive oil',
#  '10 sprigs fresh thyme',
#  '40 peeled cloves garlic',
#  'Salt and pepper']
# ['1/2 onion, thinly sliced',
#  '2 medium cucumbers, thinly sliced',
#  '1 cup water',
#  '1 cup cider vinegar',
#  '1 1/2 cups sugar',
#  'Pinch kosher salt',
#  '1/2 teaspoon mustard seeds',
#  '1/2 teaspoon turmeric',
#  '1/2 teaspoon celery seeds',
#  '1/2 teaspoon pickling spice']
# ['Vegetable oil',
#  'Salt and pepper',
#  '1360.8 gram combined beef shank and oxtail pieces',
#  '2 onions, quartered',
#  '2 ribs celery, halved',
#  '2 carrots, halved',
#  '3 cloves garlic',
#  '1 bunch parsley',
#  '1 teaspoon black peppercorns',
#  '2 quarts water']
# ['3 ancho chiles, stemmed, seeded and sliced',
#  '3 cascabel chiles, stemmed, seeded and sliced',
#  '3 dried arbol chiles, stemmed, seeded and sliced',
#  '2 tablespoons whole cumin seeds',
#  '2 tablespoons garlic powder',
#  '1 tablespoon dried oregano',
#  '1 teaspoon smoked paprika']
# ['1 cup crushed ice, plus extra for chilling glass',
#  '1/2-ounce dry vermouth',
#  '28.3 gram gin',
#  '1 olive']
# ['3/4 cup peanut oil',
#  '12 (6-inch) yellow corn tortillas',
#  'Kosher, for seasoning, plus 1 teaspoon for beef',
#  '1 medium onion, chopped',
#  '453.6 gram ground sirloin',
#  '2 cloves garlic, minced',
#  '1 recipe Taco Potion #19, recipe follows',
#  '2/3 cup low-sodium beef broth',
#  '170.1 gram panela cheese, crumbled',
#  '12 pickled jalapeno slices',
#  '1 cup shredded iceberg lettuce, optional',
#  '1 large tomato, seeded and chopped, optional',
#  '1/2 cup fresh cilantro leaves, optional']
# ['1 small package orange flavored gelatin*',
#  '1 small package lemon flavored gelatin*',
#  '2 1/2 cups boiling water',
#  '1 small can pineapple bits with juice',
#  '1/2 cup toasted, chopped pecans',
#  '1 can whole cranberry sauce']

# %%
def print_recipe(recipe):
    for k, v in recipe.items():
        if v is None:
            continue
        if k == "Categories":
            v = v.split(';')
        elif k == "Ingredients":
            v = convert_units(v, c_dict)
        if isinstance(v, list):
            print()
            print(k)
            print("=" * len(k))
            pprint(v)
        else:
            print(f'{k+":":16} {v}')
print_recipe(data['1939636'])
# Out:
# Title:           Bacon Vinaigrette with Grilled Radicchio
# Author:          Recipe courtesy of Alton Brown
# Level:           Easy
# Total:           20 min
# Prep:            10 min
# Cook:            10 min
# Yield:           8 servings
# Show:            Good Eats
# Episode:         Scrap Iron Chef
#
# Categories
# ==========
# ['American',
#  'Salad Dressing Recipes',
#  'Bacon Recipes',
#  'Meat',
#  'Lettuce Recipes',
#  'Vegetable',
#  'Side Dish',
#  'Appetizer',
#  'Grilling',
#  'Recipes for a Crowd']
#
# Ingredients
# ===========
# ['1/4 cup extra-virgin olive oil',
#  '1/4 cup cider vinegar',
#  '2 tablespoons bacon drippings',
#  '1 tablespoon dark brown sugar',
#  '1 tablespoon prepared mustard',
#  '1 teaspoon salt',
#  '1 teaspoon freshly ground pepper',
#  '2 heads radicchio, quartered']
#
# Directions
# ==========
# ['In a small non- reactive bowl combine all ingredients except radicchio. '
#  'Whisk until emulsion is formed and reserve at room temperature.',
#  'Place quartered radicchio onto a hot grill or grill pan. Cook on each side '
#  'for approximately 2 minutes per side. You are looking to achieve slightly '
#  'wilted edges.',
#  'Remove from the grill and place onto a plate. Cover with a stainless steel '
#  'bowl and allow steam to continue cooking radicchio for 5 minutes.',
#  'Drizzle vinaigrette over radicchio wedges and serve immediately.']
